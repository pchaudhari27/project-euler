# %%
import pandas as pd
import numpy as np

import math

# %% [markdown]
# From Wikipedia
# > If $(x,y)$ is a solution to $x - Dy^2 = 1$, then  $x/y$ is a convergent for $\sqrt{d}$.
#
# So we can reuse some code to find the continued fraction of $\sqrt{d}$ (problem 64) and find the convergents (problem 65).

# %%
# find continued fraction coefs
def continued_frac(n, suppress = True):
    root = math.floor(math.sqrt(n))
    if root*root == n:
        if not suppress:
            print(f'{n} is a perfect square')
            print()
        return []

    num = 0
    denom = 1
    coef = root
    period = 0
    coefs_string = f"{coef}, ( "
    coefs = [coef]

    while True:
        num = denom*coef - num
        denom = (n - num*num) // denom
        coef = (root + num) // denom

        coefs.append(coef)
        coefs_string += str(coef)
        period += 1

        if coef == 2*root:
            coefs_string += ' )'
            if not suppress:
                print(f"sqrt({n}):")
                print("coefs =", coefs_string)
                print("period =", period)
                print()
            break
            
        coefs_string += ', '

    if not suppress:
        print()

    return coefs

# %%
# find convergent based on continued fraction coefs
def convergents(series, cons_needed = 10, suppress = True):
    nums = []
    denoms = []
    for i in range(cons_needed):
        num, denom = 1, series[i]
        for j in range(1, i)[::-1]:
            next_num = series[j]
            num, denom = denom, next_num*denom + num
        
        if i > 0:
            num = series[0]*denom + num
        else:
            num, denom = denom, num

        nums.append(num)
        denoms.append(denom)
        
        if not suppress:
            print(f"n/d = {num} / {denom}")
            print()
    
    return nums, denoms

# %%
# find convergents
max_x = -1
max_d = -1
for d in range(1000):
    cs = continued_frac(d)
    if cs:
        cs = [cs[0]] + math.ceil(500/(len(cs) - 1))*cs[1:]
        ns, ds = convergents(cs, cons_needed = 500)

        for x, y in zip(ns, ds):
            if x*x - d*y*y == 1:
                print(f"minimal solution to x^2 - {d} * y^2 = 1 is x = {x}, y = {y}\n")
                if x > max_x:
                    max_x = x
                    max_d = d
                break
                
            if x == ns[-1] and y == ds[-1]:
                raise ValueError('Not Enough Values Checked')

print(max_d)
print(max_x)
# Out:
# minimal solution to x^2 - 2 * y^2 = 1 is x = 3, y = 2
#
# minimal solution to x^2 - 3 * y^2 = 1 is x = 2, y = 1
#
# minimal solution to x^2 - 5 * y^2 = 1 is x = 9, y = 4
#
# minimal solution to x^2 - 6 * y^2 = 1 is x = 5, y = 2
#
# minimal solution to x^2 - 7 * y^2 = 1 is x = 8, y = 3
#
# minimal solution to x^2 - 8 * y^2 = 1 is x = 3, y = 1
#
# minimal solution to x^2 - 10 * y^2 = 1 is x = 19, y = 6
#
# minimal solution to x^2 - 11 * y^2 = 1 is x = 10, y = 3
#
# minimal solution to x^2 - 12 * y^2 = 1 is x = 7, y = 2
#
# minimal solution to x^2 - 13 * y^2 = 1 is x = 649, y = 180
#
# minimal solution to x^2 - 14 * y^2 = 1 is x = 15, y = 4
#
# minimal solution to x^2 - 15 * y^2 = 1 is x = 4, y = 1
#
# minimal solution to x^2 - 17 * y^2 = 1 is x = 33, y = 8
#
# minimal solution to x^2 - 18 * y^2 = 1 is x = 17, y = 4
#
# minimal solution to x^2 - 19 * y^2 = 1 is x = 170, y = 39
#
# minimal solution to x^2 - 20 * y^2 = 1 is x = 9, y = 2
#
# minimal solution to x^2 - 21 * y^2 = 1 is x = 55, y = 12
#
# minimal solution to x^2 - 22 * y^2 = 1 is x = 197, y = 42
#
# minimal solution to x^2 - 23 * y^2 = 1 is x = 24, y = 5
#
# minimal solution to x^2 - 24 * y^2 = 1 is x = 5, y = 1
#
# minimal solution to x^2 - 26 * y^2 = 1 is x = 51, y = 10
#
# minimal solution to x^2 - 27 * y^2 = 1 is x = 26, y = 5
#
# minimal solution to x^2 - 28 * y^2 = 1 is x = 127, y = 24
#
# minimal solution to x^2 - 29 * y^2 = 1 is x = 9801, y = 1820
#
# minimal solution to x^2 - 30 * y^2 = 1 is x = 11, y = 2
#
# minimal solution to x^2 - 31 * y^2 = 1 is x = 1520, y = 273
#
# minimal solution to x^2 - 32 * y^2 = 1 is x = 17, y = 3
#
# minimal solution to x^2 - 33 * y^2 = 1 is x = 23, y = 4
#
# minimal solution to x^2 - 34 * y^2 = 1 is x = 35, y = 6
#
# minimal solution to x^2 - 35 * y^2 = 1 is x = 6, y = 1
#
# minimal solution to x^2 - 37 * y^2 = 1 is x = 73, y = 12
#
# minimal solution to x^2 - 38 * y^2 = 1 is x = 37, y = 6
#
# minimal solution to x^2 - 39 * y^2 = 1 is x = 25, y = 4
#
# minimal solution to x^2 - 40 * y^2 = 1 is x = 19, y = 3
#
# minimal solution to x^2 - 41 * y^2 = 1 is x = 2049, y = 320
#
# minimal solution to x^2 - 42 * y^2 = 1 is x = 13, y = 2
#
# minimal solution to x^2 - 43 * y^2 = 1 is x = 3482, y = 531
#
# minimal solution to x^2 - 44 * y^2 = 1 is x = 199, y = 30
#
# minimal solution to x^2 - 45 * y^2 = 1 is x = 161, y = 24
#
# minimal solution to x^2 - 46 * y^2 = 1 is x = 24335, y = 3588
#
# minimal solution to x^2 - 47 * y^2 = 1 is x = 48, y = 7
#
# minimal solution to x^2 - 48 * y^2 = 1 is x = 7, y = 1
#
# minimal solution to x^2 - 50 * y^2 = 1 is x = 99, y = 14
#
# minimal solution to x^2 - 51 * y^2 = 1 is x = 50, y = 7
#
# minimal solution to x^2 - 52 * y^2 = 1 is x = 649, y = 90
#
# minimal solution to x^2 - 53 * y^2 = 1 is x = 66249, y = 9100
#
# minimal solution to x^2 - 54 * y^2 = 1 is x = 485, y = 66
#
# minimal solution to x^2 - 55 * y^2 = 1 is x = 89, y = 12
#
# minimal solution to x^2 - 56 * y^2 = 1 is x = 15, y = 2
#
# minimal solution to x^2 - 57 * y^2 = 1 is x = 151, y = 20
#
# minimal solution to x^2 - 58 * y^2 = 1 is x = 19603, y = 2574
#
# minimal solution to x^2 - 59 * y^2 = 1 is x = 530, y = 69
#
# minimal solution to x^2 - 60 * y^2 = 1 is x = 31, y = 4
#
# minimal solution to x^2 - 61 * y^2 = 1 is x = 1766319049, y = 226153980
#
# minimal solution to x^2 - 62 * y^2 = 1 is x = 63, y = 8
#
# minimal solution to x^2 - 63 * y^2 = 1 is x = 8, y = 1
#
# minimal solution to x^2 - 65 * y^2 = 1 is x = 129, y = 16
#
# minimal solution to x^2 - 66 * y^2 = 1 is x = 65, y = 8
#
# minimal solution to x^2 - 67 * y^2 = 1 is x = 48842, y = 5967
#
# minimal solution to x^2 - 68 * y^2 = 1 is x = 33, y = 4
#
# minimal solution to x^2 - 69 * y^2 = 1 is x = 7775, y = 936
#
# minimal solution to x^2 - 70 * y^2 = 1 is x = 251, y = 30
#
# minimal solution to x^2 - 71 * y^2 = 1 is x = 3480, y = 413
#
# minimal solution to x^2 - 72 * y^2 = 1 is x = 17, y = 2
#
# minimal solution to x^2 - 73 * y^2 = 1 is x = 2281249, y = 267000
#
# minimal solution to x^2 - 74 * y^2 = 1 is x = 3699, y = 430
#
# minimal solution to x^2 - 75 * y^2 = 1 is x = 26, y = 3
#
# minimal solution to x^2 - 76 * y^2 = 1 is x = 57799, y = 6630
#
# minimal solution to x^2 - 77 * y^2 = 1 is x = 351, y = 40
#
# minimal solution to x^2 - 78 * y^2 = 1 is x = 53, y = 6
#
# minimal solution to x^2 - 79 * y^2 = 1 is x = 80, y = 9
#
# minimal solution to x^2 - 80 * y^2 = 1 is x = 9, y = 1
#
# minimal solution to x^2 - 82 * y^2 = 1 is x = 163, y = 18
#
# minimal solution to x^2 - 83 * y^2 = 1 is x = 82, y = 9
#
# minimal solution to x^2 - 84 * y^2 = 1 is x = 55, y = 6
#
# minimal solution to x^2 - 85 * y^2 = 1 is x = 285769, y = 30996
#
# minimal solution to x^2 - 86 * y^2 = 1 is x = 10405, y = 1122
#
# minimal solution to x^2 - 87 * y^2 = 1 is x = 28, y = 3
#
# minimal solution to x^2 - 88 * y^2 = 1 is x = 197, y = 21
#
# minimal solution to x^2 - 89 * y^2 = 1 is x = 500001, y = 53000
#
# minimal solution to x^2 - 90 * y^2 = 1 is x = 19, y = 2
#
# minimal solution to x^2 - 91 * y^2 = 1 is x = 1574, y = 165
#
# minimal solution to x^2 - 92 * y^2 = 1 is x = 1151, y = 120
#
# minimal solution to x^2 - 93 * y^2 = 1 is x = 12151, y = 1260
#
# minimal solution to x^2 - 94 * y^2 = 1 is x = 2143295, y = 221064
#
# minimal solution to x^2 - 95 * y^2 = 1 is x = 39, y = 4
#
# minimal solution to x^2 - 96 * y^2 = 1 is x = 49, y = 5
#
# minimal solution to x^2 - 97 * y^2 = 1 is x = 62809633, y = 6377352
#
# minimal solution to x^2 - 98 * y^2 = 1 is x = 99, y = 10
#
# minimal solution to x^2 - 99 * y^2 = 1 is x = 10, y = 1
#
# minimal solution to x^2 - 101 * y^2 = 1 is x = 201, y = 20
#
# minimal solution to x^2 - 102 * y^2 = 1 is x = 101, y = 10
#
# minimal solution to x^2 - 103 * y^2 = 1 is x = 227528, y = 22419
#
# minimal solution to x^2 - 104 * y^2 = 1 is x = 51, y = 5
#
# minimal solution to x^2 - 105 * y^2 = 1 is x = 41, y = 4
#
# minimal solution to x^2 - 106 * y^2 = 1 is x = 32080051, y = 3115890
#
# minimal solution to x^2 - 107 * y^2 = 1 is x = 962, y = 93
#
# minimal solution to x^2 - 108 * y^2 = 1 is x = 1351, y = 130
#
# minimal solution to x^2 - 109 * y^2 = 1 is x = 158070671986249, y = 15140424455100
#
# minimal solution to x^2 - 110 * y^2 = 1 is x = 21, y = 2
#
# minimal solution to x^2 - 111 * y^2 = 1 is x = 295, y = 28
#
# minimal solution to x^2 - 112 * y^2 = 1 is x = 127, y = 12
#
# minimal solution to x^2 - 113 * y^2 = 1 is x = 1204353, y = 113296
#
# minimal solution to x^2 - 114 * y^2 = 1 is x = 1025, y = 96
#
# minimal solution to x^2 - 115 * y^2 = 1 is x = 1126, y = 105
#
# minimal solution to x^2 - 116 * y^2 = 1 is x = 9801, y = 910
#
# minimal solution to x^2 - 117 * y^2 = 1 is x = 649, y = 60
#
# minimal solution to x^2 - 118 * y^2 = 1 is x = 306917, y = 28254
#
# minimal solution to x^2 - 119 * y^2 = 1 is x = 120, y = 11
#
# minimal solution to x^2 - 120 * y^2 = 1 is x = 11, y = 1
#
# minimal solution to x^2 - 122 * y^2 = 1 is x = 243, y = 22
#
# minimal solution to x^2 - 123 * y^2 = 1 is x = 122, y = 11
#
# minimal solution to x^2 - 124 * y^2 = 1 is x = 4620799, y = 414960
#
# minimal solution to x^2 - 125 * y^2 = 1 is x = 930249, y = 83204
#
# minimal solution to x^2 - 126 * y^2 = 1 is x = 449, y = 40
#
# minimal solution to x^2 - 127 * y^2 = 1 is x = 4730624, y = 419775
#
# minimal solution to x^2 - 128 * y^2 = 1 is x = 577, y = 51
#
# minimal solution to x^2 - 129 * y^2 = 1 is x = 16855, y = 1484
#
# minimal solution to x^2 - 130 * y^2 = 1 is x = 6499, y = 570
#
# minimal solution to x^2 - 131 * y^2 = 1 is x = 10610, y = 927
#
# minimal solution to x^2 - 132 * y^2 = 1 is x = 23, y = 2
#
# minimal solution to x^2 - 133 * y^2 = 1 is x = 2588599, y = 224460
#
# minimal solution to x^2 - 134 * y^2 = 1 is x = 145925, y = 12606
#
# minimal solution to x^2 - 135 * y^2 = 1 is x = 244, y = 21
#
# minimal solution to x^2 - 136 * y^2 = 1 is x = 35, y = 3
#
# minimal solution to x^2 - 137 * y^2 = 1 is x = 6083073, y = 519712
#
# minimal solution to x^2 - 138 * y^2 = 1 is x = 47, y = 4
#
# minimal solution to x^2 - 139 * y^2 = 1 is x = 77563250, y = 6578829
#
# minimal solution to x^2 - 140 * y^2 = 1 is x = 71, y = 6
#
# minimal solution to x^2 - 141 * y^2 = 1 is x = 95, y = 8
#
# minimal solution to x^2 - 142 * y^2 = 1 is x = 143, y = 12
#
# minimal solution to x^2 - 143 * y^2 = 1 is x = 12, y = 1
#
# minimal solution to x^2 - 145 * y^2 = 1 is x = 289, y = 24
#
# minimal solution to x^2 - 146 * y^2 = 1 is x = 145, y = 12
#
# minimal solution to x^2 - 147 * y^2 = 1 is x = 97, y = 8
#
# minimal solution to x^2 - 148 * y^2 = 1 is x = 73, y = 6
#
# minimal solution to x^2 - 149 * y^2 = 1 is x = 25801741449, y = 2113761020
#
# minimal solution to x^2 - 150 * y^2 = 1 is x = 49, y = 4
#
# minimal solution to x^2 - 151 * y^2 = 1 is x = 1728148040, y = 140634693
#
# minimal solution to x^2 - 152 * y^2 = 1 is x = 37, y = 3
#
# minimal solution to x^2 - 153 * y^2 = 1 is x = 2177, y = 176
#
# minimal solution to x^2 - 154 * y^2 = 1 is x = 21295, y = 1716
#
# minimal solution to x^2 - 155 * y^2 = 1 is x = 249, y = 20
#
# minimal solution to x^2 - 156 * y^2 = 1 is x = 25, y = 2
#
# minimal solution to x^2 - 157 * y^2 = 1 is x = 46698728731849, y = 3726964292220
#
# minimal solution to x^2 - 158 * y^2 = 1 is x = 7743, y = 616
#
# minimal solution to x^2 - 159 * y^2 = 1 is x = 1324, y = 105
#
# minimal solution to x^2 - 160 * y^2 = 1 is x = 721, y = 57
#
# minimal solution to x^2 - 161 * y^2 = 1 is x = 11775, y = 928
#
# minimal solution to x^2 - 162 * y^2 = 1 is x = 19601, y = 1540
#
# minimal solution to x^2 - 163 * y^2 = 1 is x = 64080026, y = 5019135
#
# minimal solution to x^2 - 164 * y^2 = 1 is x = 2049, y = 160
#
# minimal solution to x^2 - 165 * y^2 = 1 is x = 1079, y = 84
#
# minimal solution to x^2 - 166 * y^2 = 1 is x = 1700902565, y = 132015642
#
# minimal solution to x^2 - 167 * y^2 = 1 is x = 168, y = 13
#
# minimal solution to x^2 - 168 * y^2 = 1 is x = 13, y = 1
#
# minimal solution to x^2 - 170 * y^2 = 1 is x = 339, y = 26
#
# minimal solution to x^2 - 171 * y^2 = 1 is x = 170, y = 13
#
# minimal solution to x^2 - 172 * y^2 = 1 is x = 24248647, y = 1848942
#
# minimal solution to x^2 - 173 * y^2 = 1 is x = 2499849, y = 190060
#
# minimal solution to x^2 - 174 * y^2 = 1 is x = 1451, y = 110
#
# minimal solution to x^2 - 175 * y^2 = 1 is x = 2024, y = 153
#
# minimal solution to x^2 - 176 * y^2 = 1 is x = 199, y = 15
#
# minimal solution to x^2 - 177 * y^2 = 1 is x = 62423, y = 4692
#
# minimal solution to x^2 - 178 * y^2 = 1 is x = 1601, y = 120
#
# minimal solution to x^2 - 179 * y^2 = 1 is x = 4190210, y = 313191
#
# minimal solution to x^2 - 180 * y^2 = 1 is x = 161, y = 12
#
# minimal solution to x^2 - 181 * y^2 = 1 is x = 2469645423824185801, y = 183567298683461940
#
# minimal solution to x^2 - 182 * y^2 = 1 is x = 27, y = 2
#
# minimal solution to x^2 - 183 * y^2 = 1 is x = 487, y = 36
#
# minimal solution to x^2 - 184 * y^2 = 1 is x = 24335, y = 1794
#
# minimal solution to x^2 - 185 * y^2 = 1 is x = 9249, y = 680
#
# minimal solution to x^2 - 186 * y^2 = 1 is x = 7501, y = 550
#
# minimal solution to x^2 - 187 * y^2 = 1 is x = 1682, y = 123
#
# minimal solution to x^2 - 188 * y^2 = 1 is x = 4607, y = 336
#
# minimal solution to x^2 - 189 * y^2 = 1 is x = 55, y = 4
#
# minimal solution to x^2 - 190 * y^2 = 1 is x = 52021, y = 3774
#
# minimal solution to x^2 - 191 * y^2 = 1 is x = 8994000, y = 650783
#
# minimal solution to x^2 - 192 * y^2 = 1 is x = 97, y = 7
#
# minimal solution to x^2 - 193 * y^2 = 1 is x = 6224323426849, y = 448036604040
#
# minimal solution to x^2 - 194 * y^2 = 1 is x = 195, y = 14
#
# minimal solution to x^2 - 195 * y^2 = 1 is x = 14, y = 1
#
# minimal solution to x^2 - 197 * y^2 = 1 is x = 393, y = 28
#
# minimal solution to x^2 - 198 * y^2 = 1 is x = 197, y = 14
#
# minimal solution to x^2 - 199 * y^2 = 1 is x = 16266196520, y = 1153080099
#
# minimal solution to x^2 - 200 * y^2 = 1 is x = 99, y = 7
#
# minimal solution to x^2 - 201 * y^2 = 1 is x = 515095, y = 36332
#
# minimal solution to x^2 - 202 * y^2 = 1 is x = 19731763, y = 1388322
#
# minimal solution to x^2 - 203 * y^2 = 1 is x = 57, y = 4
#
# minimal solution to x^2 - 204 * y^2 = 1 is x = 4999, y = 350
#
# minimal solution to x^2 - 205 * y^2 = 1 is x = 39689, y = 2772
#
# minimal solution to x^2 - 206 * y^2 = 1 is x = 59535, y = 4148
#
# minimal solution to x^2 - 207 * y^2 = 1 is x = 1151, y = 80
#
# minimal solution to x^2 - 208 * y^2 = 1 is x = 649, y = 45
#
# minimal solution to x^2 - 209 * y^2 = 1 is x = 46551, y = 3220
#
# minimal solution to x^2 - 210 * y^2 = 1 is x = 29, y = 2
#
# minimal solution to x^2 - 211 * y^2 = 1 is x = 278354373650, y = 19162705353
#
# minimal solution to x^2 - 212 * y^2 = 1 is x = 66249, y = 4550
#
# minimal solution to x^2 - 213 * y^2 = 1 is x = 194399, y = 13320
#
# minimal solution to x^2 - 214 * y^2 = 1 is x = 695359189925, y = 47533775646
#
# minimal solution to x^2 - 215 * y^2 = 1 is x = 44, y = 3
#
# minimal solution to x^2 - 216 * y^2 = 1 is x = 485, y = 33
#
# minimal solution to x^2 - 217 * y^2 = 1 is x = 3844063, y = 260952
#
# minimal solution to x^2 - 218 * y^2 = 1 is x = 126003, y = 8534
#
# minimal solution to x^2 - 219 * y^2 = 1 is x = 74, y = 5
#
# minimal solution to x^2 - 220 * y^2 = 1 is x = 89, y = 6
#
# minimal solution to x^2 - 221 * y^2 = 1 is x = 1665, y = 112
#
# minimal solution to x^2 - 222 * y^2 = 1 is x = 149, y = 10
#
# minimal solution to x^2 - 223 * y^2 = 1 is x = 224, y = 15
#
# minimal solution to x^2 - 224 * y^2 = 1 is x = 15, y = 1
#
# minimal solution to x^2 - 226 * y^2 = 1 is x = 451, y = 30
#
# minimal solution to x^2 - 227 * y^2 = 1 is x = 226, y = 15
#
# minimal solution to x^2 - 228 * y^2 = 1 is x = 151, y = 10
#
# minimal solution to x^2 - 229 * y^2 = 1 is x = 5848201, y = 386460
#
# minimal solution to x^2 - 230 * y^2 = 1 is x = 91, y = 6
#
# minimal solution to x^2 - 231 * y^2 = 1 is x = 76, y = 5
#
# minimal solution to x^2 - 232 * y^2 = 1 is x = 19603, y = 1287
#
# minimal solution to x^2 - 233 * y^2 = 1 is x = 1072400673, y = 70255304
#
# minimal solution to x^2 - 234 * y^2 = 1 is x = 5201, y = 340
#
# minimal solution to x^2 - 235 * y^2 = 1 is x = 46, y = 3
#
# minimal solution to x^2 - 236 * y^2 = 1 is x = 561799, y = 36570
#
# minimal solution to x^2 - 237 * y^2 = 1 is x = 228151, y = 14820
#
# minimal solution to x^2 - 238 * y^2 = 1 is x = 11663, y = 756
#
# minimal solution to x^2 - 239 * y^2 = 1 is x = 6195120, y = 400729
#
# minimal solution to x^2 - 240 * y^2 = 1 is x = 31, y = 2
#
# minimal solution to x^2 - 241 * y^2 = 1 is x = 10085143557001249, y = 649641205044600
#
# minimal solution to x^2 - 242 * y^2 = 1 is x = 19601, y = 1260
#
# minimal solution to x^2 - 243 * y^2 = 1 is x = 70226, y = 4505
#
# minimal solution to x^2 - 244 * y^2 = 1 is x = 1766319049, y = 113076990
#
# minimal solution to x^2 - 245 * y^2 = 1 is x = 51841, y = 3312
#
# minimal solution to x^2 - 246 * y^2 = 1 is x = 88805, y = 5662
#
# minimal solution to x^2 - 247 * y^2 = 1 is x = 85292, y = 5427
#
# minimal solution to x^2 - 248 * y^2 = 1 is x = 63, y = 4
#
# minimal solution to x^2 - 249 * y^2 = 1 is x = 8553815, y = 542076
#
# minimal solution to x^2 - 250 * y^2 = 1 is x = 39480499, y = 2496966
#
# minimal solution to x^2 - 251 * y^2 = 1 is x = 3674890, y = 231957
#
# minimal solution to x^2 - 252 * y^2 = 1 is x = 127, y = 8
#
# minimal solution to x^2 - 253 * y^2 = 1 is x = 3222617399, y = 202604220
#
# minimal solution to x^2 - 254 * y^2 = 1 is x = 255, y = 16
#
# minimal solution to x^2 - 255 * y^2 = 1 is x = 16, y = 1
#
# minimal solution to x^2 - 257 * y^2 = 1 is x = 513, y = 32
#
# minimal solution to x^2 - 258 * y^2 = 1 is x = 257, y = 16
#
# minimal solution to x^2 - 259 * y^2 = 1 is x = 847225, y = 52644
#
# minimal solution to x^2 - 260 * y^2 = 1 is x = 129, y = 8
#
# minimal solution to x^2 - 261 * y^2 = 1 is x = 192119201, y = 11891880
#
# minimal solution to x^2 - 262 * y^2 = 1 is x = 104980517, y = 6485718
#
# minimal solution to x^2 - 263 * y^2 = 1 is x = 139128, y = 8579
#
# minimal solution to x^2 - 264 * y^2 = 1 is x = 65, y = 4
#
# minimal solution to x^2 - 265 * y^2 = 1 is x = 73738369, y = 4529712
#
# minimal solution to x^2 - 266 * y^2 = 1 is x = 685, y = 42
#
# minimal solution to x^2 - 267 * y^2 = 1 is x = 2402, y = 147
#
# minimal solution to x^2 - 268 * y^2 = 1 is x = 4771081927, y = 291440214
#
# minimal solution to x^2 - 269 * y^2 = 1 is x = 13449, y = 820
#
# minimal solution to x^2 - 270 * y^2 = 1 is x = 5291, y = 322
#
# minimal solution to x^2 - 271 * y^2 = 1 is x = 115974983600, y = 7044978537
#
# minimal solution to x^2 - 272 * y^2 = 1 is x = 33, y = 2
#
# minimal solution to x^2 - 273 * y^2 = 1 is x = 727, y = 44
#
# minimal solution to x^2 - 274 * y^2 = 1 is x = 3959299, y = 239190
#
# minimal solution to x^2 - 275 * y^2 = 1 is x = 199, y = 12
#
# minimal solution to x^2 - 276 * y^2 = 1 is x = 7775, y = 468
#
# minimal solution to x^2 - 277 * y^2 = 1 is x = 159150073798980475849, y = 9562401173878027020
#
# minimal solution to x^2 - 278 * y^2 = 1 is x = 2501, y = 150
#
# minimal solution to x^2 - 279 * y^2 = 1 is x = 1520, y = 91
#
# minimal solution to x^2 - 280 * y^2 = 1 is x = 251, y = 15
#
# minimal solution to x^2 - 281 * y^2 = 1 is x = 2262200630049, y = 134951575480
#
# minimal solution to x^2 - 282 * y^2 = 1 is x = 2351, y = 140
#
# minimal solution to x^2 - 283 * y^2 = 1 is x = 138274082, y = 8219541
#
# minimal solution to x^2 - 284 * y^2 = 1 is x = 24220799, y = 1437240
#
# minimal solution to x^2 - 285 * y^2 = 1 is x = 2431, y = 144
#
# minimal solution to x^2 - 286 * y^2 = 1 is x = 561835, y = 33222
#
# minimal solution to x^2 - 287 * y^2 = 1 is x = 288, y = 17
#
# minimal solution to x^2 - 288 * y^2 = 1 is x = 17, y = 1
#
# minimal solution to x^2 - 290 * y^2 = 1 is x = 579, y = 34
#
# minimal solution to x^2 - 291 * y^2 = 1 is x = 290, y = 17
#
# minimal solution to x^2 - 292 * y^2 = 1 is x = 2281249, y = 133500
#
# minimal solution to x^2 - 293 * y^2 = 1 is x = 12320649, y = 719780
#
# minimal solution to x^2 - 294 * y^2 = 1 is x = 4801, y = 280
#
# minimal solution to x^2 - 295 * y^2 = 1 is x = 2024999, y = 117900
#
# minimal solution to x^2 - 296 * y^2 = 1 is x = 3699, y = 215
#
# minimal solution to x^2 - 297 * y^2 = 1 is x = 48599, y = 2820
#
# minimal solution to x^2 - 298 * y^2 = 1 is x = 335473872499, y = 19433479650
#
# minimal solution to x^2 - 299 * y^2 = 1 is x = 415, y = 24
#
# minimal solution to x^2 - 300 * y^2 = 1 is x = 1351, y = 78
#
# minimal solution to x^2 - 301 * y^2 = 1 is x = 5883392537695, y = 339113108232
#
# minimal solution to x^2 - 302 * y^2 = 1 is x = 4276623, y = 246092
#
# minimal solution to x^2 - 303 * y^2 = 1 is x = 2524, y = 145
#
# minimal solution to x^2 - 304 * y^2 = 1 is x = 57799, y = 3315
#
# minimal solution to x^2 - 305 * y^2 = 1 is x = 489, y = 28
#
# minimal solution to x^2 - 306 * y^2 = 1 is x = 35, y = 2
#
# minimal solution to x^2 - 307 * y^2 = 1 is x = 88529282, y = 5052633
#
# minimal solution to x^2 - 308 * y^2 = 1 is x = 351, y = 20
#
# minimal solution to x^2 - 309 * y^2 = 1 is x = 64202725495, y = 3652365444
#
# minimal solution to x^2 - 310 * y^2 = 1 is x = 848719, y = 48204
#
# minimal solution to x^2 - 311 * y^2 = 1 is x = 16883880, y = 957397
#
# minimal solution to x^2 - 312 * y^2 = 1 is x = 53, y = 3
#
# minimal solution to x^2 - 313 * y^2 = 1 is x = 32188120829134849, y = 1819380158564160
#
# minimal solution to x^2 - 314 * y^2 = 1 is x = 392499, y = 22150
#
# minimal solution to x^2 - 315 * y^2 = 1 is x = 71, y = 4
#
# minimal solution to x^2 - 316 * y^2 = 1 is x = 12799, y = 720
#
# minimal solution to x^2 - 317 * y^2 = 1 is x = 248678907849, y = 13967198980
#
# minimal solution to x^2 - 318 * y^2 = 1 is x = 107, y = 6
#
# minimal solution to x^2 - 319 * y^2 = 1 is x = 12901780, y = 722361
#
# minimal solution to x^2 - 320 * y^2 = 1 is x = 161, y = 9
#
# minimal solution to x^2 - 321 * y^2 = 1 is x = 215, y = 12
#
# minimal solution to x^2 - 322 * y^2 = 1 is x = 323, y = 18
#
# minimal solution to x^2 - 323 * y^2 = 1 is x = 18, y = 1
#
# minimal solution to x^2 - 325 * y^2 = 1 is x = 649, y = 36
#
# minimal solution to x^2 - 326 * y^2 = 1 is x = 325, y = 18
#
# minimal solution to x^2 - 327 * y^2 = 1 is x = 217, y = 12
#
# minimal solution to x^2 - 328 * y^2 = 1 is x = 163, y = 9
#
# minimal solution to x^2 - 329 * y^2 = 1 is x = 2376415, y = 131016
#
# minimal solution to x^2 - 330 * y^2 = 1 is x = 109, y = 6
#
# minimal solution to x^2 - 331 * y^2 = 1 is x = 2785589801443970, y = 153109862634573
#
# minimal solution to x^2 - 332 * y^2 = 1 is x = 13447, y = 738
#
# minimal solution to x^2 - 333 * y^2 = 1 is x = 73, y = 4
#
# minimal solution to x^2 - 334 * y^2 = 1 is x = 63804373719695, y = 3491219999244
#
# minimal solution to x^2 - 335 * y^2 = 1 is x = 604, y = 33
#
# minimal solution to x^2 - 336 * y^2 = 1 is x = 55, y = 3
#
# minimal solution to x^2 - 337 * y^2 = 1 is x = 2063810353129713793, y = 112422913565764752
#
# minimal solution to x^2 - 338 * y^2 = 1 is x = 114243, y = 6214
#
# minimal solution to x^2 - 339 * y^2 = 1 is x = 97970, y = 5321
#
# minimal solution to x^2 - 340 * y^2 = 1 is x = 285769, y = 15498
#
# minimal solution to x^2 - 341 * y^2 = 1 is x = 10626551, y = 575460
#
# minimal solution to x^2 - 342 * y^2 = 1 is x = 37, y = 2
#
# minimal solution to x^2 - 343 * y^2 = 1 is x = 130576328, y = 7050459
#
# minimal solution to x^2 - 344 * y^2 = 1 is x = 10405, y = 561
#
# minimal solution to x^2 - 345 * y^2 = 1 is x = 6761, y = 364
#
# minimal solution to x^2 - 346 * y^2 = 1 is x = 17299, y = 930
#
# minimal solution to x^2 - 347 * y^2 = 1 is x = 641602, y = 34443
#
# minimal solution to x^2 - 348 * y^2 = 1 is x = 1567, y = 84
#
# minimal solution to x^2 - 349 * y^2 = 1 is x = 169648201, y = 9081060
#
# minimal solution to x^2 - 350 * y^2 = 1 is x = 449, y = 24
#
# minimal solution to x^2 - 351 * y^2 = 1 is x = 62425, y = 3332
#
# minimal solution to x^2 - 352 * y^2 = 1 is x = 77617, y = 4137
#
# minimal solution to x^2 - 353 * y^2 = 1 is x = 10157115393, y = 540608704
#
# minimal solution to x^2 - 354 * y^2 = 1 is x = 258065, y = 13716
#
# minimal solution to x^2 - 355 * y^2 = 1 is x = 954809, y = 50676
#
# minimal solution to x^2 - 356 * y^2 = 1 is x = 500001, y = 26500
#
# minimal solution to x^2 - 357 * y^2 = 1 is x = 3401, y = 180
#
# minimal solution to x^2 - 358 * y^2 = 1 is x = 176579805797, y = 9332532726
#
# minimal solution to x^2 - 359 * y^2 = 1 is x = 360, y = 19
#
# minimal solution to x^2 - 360 * y^2 = 1 is x = 19, y = 1
#
# minimal solution to x^2 - 362 * y^2 = 1 is x = 723, y = 38
#
# minimal solution to x^2 - 363 * y^2 = 1 is x = 362, y = 19
#
# minimal solution to x^2 - 364 * y^2 = 1 is x = 4954951, y = 259710
#
# minimal solution to x^2 - 365 * y^2 = 1 is x = 23915529, y = 1251796
#
# minimal solution to x^2 - 366 * y^2 = 1 is x = 907925, y = 47458
#
# minimal solution to x^2 - 367 * y^2 = 1 is x = 19019995568, y = 992835687
#
# minimal solution to x^2 - 368 * y^2 = 1 is x = 1151, y = 60
#
# minimal solution to x^2 - 369 * y^2 = 1 is x = 8396801, y = 437120
#
# minimal solution to x^2 - 370 * y^2 = 1 is x = 213859, y = 11118
#
# minimal solution to x^2 - 371 * y^2 = 1 is x = 1695, y = 88
#
# minimal solution to x^2 - 372 * y^2 = 1 is x = 12151, y = 630
#
# minimal solution to x^2 - 373 * y^2 = 1 is x = 52387849, y = 2712540
#
# minimal solution to x^2 - 374 * y^2 = 1 is x = 3365, y = 174
#
# minimal solution to x^2 - 375 * y^2 = 1 is x = 15124, y = 781
#
# minimal solution to x^2 - 376 * y^2 = 1 is x = 2143295, y = 110532
#
# minimal solution to x^2 - 377 * y^2 = 1 is x = 233, y = 12
#
# minimal solution to x^2 - 378 * y^2 = 1 is x = 8749, y = 450
#
# minimal solution to x^2 - 379 * y^2 = 1 is x = 12941197220540690, y = 664744650125541
#
# minimal solution to x^2 - 380 * y^2 = 1 is x = 39, y = 2
#
# minimal solution to x^2 - 381 * y^2 = 1 is x = 1015, y = 52
#
# minimal solution to x^2 - 382 * y^2 = 1 is x = 164998439999, y = 8442054600
#
# minimal solution to x^2 - 383 * y^2 = 1 is x = 18768, y = 959
#
# minimal solution to x^2 - 384 * y^2 = 1 is x = 4801, y = 245
#
# minimal solution to x^2 - 385 * y^2 = 1 is x = 95831, y = 4884
#
# minimal solution to x^2 - 386 * y^2 = 1 is x = 111555, y = 5678
#
# minimal solution to x^2 - 387 * y^2 = 1 is x = 3482, y = 177
#
# minimal solution to x^2 - 388 * y^2 = 1 is x = 62809633, y = 3188676
#
# minimal solution to x^2 - 389 * y^2 = 1 is x = 3287049, y = 166660
#
# minimal solution to x^2 - 390 * y^2 = 1 is x = 79, y = 4
#
# minimal solution to x^2 - 391 * y^2 = 1 is x = 7338680, y = 371133
#
# minimal solution to x^2 - 392 * y^2 = 1 is x = 99, y = 5
#
# minimal solution to x^2 - 393 * y^2 = 1 is x = 46437143, y = 2342444
#
# minimal solution to x^2 - 394 * y^2 = 1 is x = 312086396361222451, y = 15722685507826110
#
# minimal solution to x^2 - 395 * y^2 = 1 is x = 159, y = 8
#
# minimal solution to x^2 - 396 * y^2 = 1 is x = 199, y = 10
#
# minimal solution to x^2 - 397 * y^2 = 1 is x = 838721786045180184649, y = 42094239791738433660
#
# minimal solution to x^2 - 398 * y^2 = 1 is x = 399, y = 20
#
# minimal solution to x^2 - 399 * y^2 = 1 is x = 20, y = 1
#
# minimal solution to x^2 - 401 * y^2 = 1 is x = 801, y = 40
#
# minimal solution to x^2 - 402 * y^2 = 1 is x = 401, y = 20
#
# minimal solution to x^2 - 403 * y^2 = 1 is x = 669878, y = 33369
#
# minimal solution to x^2 - 404 * y^2 = 1 is x = 201, y = 10
#
# minimal solution to x^2 - 405 * y^2 = 1 is x = 161, y = 8
#
# minimal solution to x^2 - 406 * y^2 = 1 is x = 59468095, y = 2951352
#
# minimal solution to x^2 - 407 * y^2 = 1 is x = 2663, y = 132
#
# minimal solution to x^2 - 408 * y^2 = 1 is x = 101, y = 5
#
# minimal solution to x^2 - 409 * y^2 = 1 is x = 25052977273092427986049, y = 1238789998647218582160
#
# minimal solution to x^2 - 410 * y^2 = 1 is x = 81, y = 4
#
# minimal solution to x^2 - 411 * y^2 = 1 is x = 49730, y = 2453
#
# minimal solution to x^2 - 412 * y^2 = 1 is x = 103537981567, y = 5100950232
#
# minimal solution to x^2 - 413 * y^2 = 1 is x = 113399, y = 5580
#
# minimal solution to x^2 - 414 * y^2 = 1 is x = 24335, y = 1196
#
# minimal solution to x^2 - 415 * y^2 = 1 is x = 18412804, y = 903849
#
# minimal solution to x^2 - 416 * y^2 = 1 is x = 5201, y = 255
#
# minimal solution to x^2 - 417 * y^2 = 1 is x = 85322647, y = 4178268
#
# minimal solution to x^2 - 418 * y^2 = 1 is x = 33857, y = 1656
#
# minimal solution to x^2 - 419 * y^2 = 1 is x = 270174970, y = 13198911
#
# minimal solution to x^2 - 420 * y^2 = 1 is x = 41, y = 2
#
# minimal solution to x^2 - 421 * y^2 = 1 is x = 3879474045914926879468217167061449, y = 189073995951839020880499780706260
#
# minimal solution to x^2 - 422 * y^2 = 1 is x = 7022501, y = 341850
#
# minimal solution to x^2 - 423 * y^2 = 1 is x = 4607, y = 224
#
# minimal solution to x^2 - 424 * y^2 = 1 is x = 32080051, y = 1557945
#
# minimal solution to x^2 - 425 * y^2 = 1 is x = 143649, y = 6968
#
# minimal solution to x^2 - 426 * y^2 = 1 is x = 88751, y = 4300
#
# minimal solution to x^2 - 427 * y^2 = 1 is x = 62, y = 3
#
# minimal solution to x^2 - 428 * y^2 = 1 is x = 1850887, y = 89466
#
# minimal solution to x^2 - 429 * y^2 = 1 is x = 1524095, y = 73584
#
# minimal solution to x^2 - 430 * y^2 = 1 is x = 2862251, y = 138030
#
# minimal solution to x^2 - 431 * y^2 = 1 is x = 151560720, y = 7300423
#
# minimal solution to x^2 - 432 * y^2 = 1 is x = 1351, y = 65
#
# minimal solution to x^2 - 433 * y^2 = 1 is x = 104564907854286695713, y = 5025068784834899736
#
# minimal solution to x^2 - 434 * y^2 = 1 is x = 125, y = 6
#
# minimal solution to x^2 - 435 * y^2 = 1 is x = 146, y = 7
#
# minimal solution to x^2 - 436 * y^2 = 1 is x = 158070671986249, y = 7570212227550
#
# minimal solution to x^2 - 437 * y^2 = 1 is x = 4599, y = 220
#
# minimal solution to x^2 - 438 * y^2 = 1 is x = 293, y = 14
#
# minimal solution to x^2 - 439 * y^2 = 1 is x = 440, y = 21
#
# minimal solution to x^2 - 440 * y^2 = 1 is x = 21, y = 1
#
# minimal solution to x^2 - 442 * y^2 = 1 is x = 883, y = 42
#
# minimal solution to x^2 - 443 * y^2 = 1 is x = 442, y = 21
#
# minimal solution to x^2 - 444 * y^2 = 1 is x = 295, y = 14
#
# minimal solution to x^2 - 445 * y^2 = 1 is x = 43468489, y = 2060604
#
# minimal solution to x^2 - 446 * y^2 = 1 is x = 110166015, y = 5216512
#
# minimal solution to x^2 - 447 * y^2 = 1 is x = 148, y = 7
#
# minimal solution to x^2 - 448 * y^2 = 1 is x = 127, y = 6
#
# minimal solution to x^2 - 449 * y^2 = 1 is x = 71798771299708449, y = 3388393513402120
#
# minimal solution to x^2 - 450 * y^2 = 1 is x = 19601, y = 924
#
# minimal solution to x^2 - 451 * y^2 = 1 is x = 46471490, y = 2188257
#
# minimal solution to x^2 - 452 * y^2 = 1 is x = 1204353, y = 56648
#
# minimal solution to x^2 - 453 * y^2 = 1 is x = 1653751, y = 77700
#
# minimal solution to x^2 - 454 * y^2 = 1 is x = 16916040084175685, y = 793909098494766
#
# minimal solution to x^2 - 455 * y^2 = 1 is x = 64, y = 3
#
# minimal solution to x^2 - 456 * y^2 = 1 is x = 1025, y = 48
#
# minimal solution to x^2 - 457 * y^2 = 1 is x = 6983244756398928218113, y = 326662411570389853632
#
# minimal solution to x^2 - 458 * y^2 = 1 is x = 22899, y = 1070
#
# minimal solution to x^2 - 459 * y^2 = 1 is x = 499850, y = 23331
#
# minimal solution to x^2 - 460 * y^2 = 1 is x = 2535751, y = 118230
#
# minimal solution to x^2 - 461 * y^2 = 1 is x = 1182351890184201, y = 55067617520620
#
# minimal solution to x^2 - 462 * y^2 = 1 is x = 43, y = 2
#
# minimal solution to x^2 - 463 * y^2 = 1 is x = 247512720456368, y = 11502891625161
#
# minimal solution to x^2 - 464 * y^2 = 1 is x = 9801, y = 455
#
# minimal solution to x^2 - 465 * y^2 = 1 is x = 15871, y = 736
#
# minimal solution to x^2 - 466 * y^2 = 1 is x = 938319425, y = 43466808
#
# minimal solution to x^2 - 467 * y^2 = 1 is x = 1625626, y = 75225
#
# minimal solution to x^2 - 468 * y^2 = 1 is x = 649, y = 30
#
# minimal solution to x^2 - 469 * y^2 = 1 is x = 137215, y = 6336
#
# minimal solution to x^2 - 470 * y^2 = 1 is x = 1691, y = 78
#
# minimal solution to x^2 - 471 * y^2 = 1 is x = 7838695, y = 361188
#
# minimal solution to x^2 - 472 * y^2 = 1 is x = 306917, y = 14127
#
# minimal solution to x^2 - 473 * y^2 = 1 is x = 87, y = 4
#
# minimal solution to x^2 - 474 * y^2 = 1 is x = 193549, y = 8890
#
# minimal solution to x^2 - 475 * y^2 = 1 is x = 57799, y = 2652
#
# minimal solution to x^2 - 476 * y^2 = 1 is x = 28799, y = 1320
#
# minimal solution to x^2 - 477 * y^2 = 1 is x = 8777860001, y = 401910600
#
# minimal solution to x^2 - 478 * y^2 = 1 is x = 1617319577991743, y = 73974475657896
#
# minimal solution to x^2 - 479 * y^2 = 1 is x = 2989440, y = 136591
#
# minimal solution to x^2 - 480 * y^2 = 1 is x = 241, y = 11
#
# minimal solution to x^2 - 481 * y^2 = 1 is x = 1859131879201, y = 84769117080
#
# minimal solution to x^2 - 482 * y^2 = 1 is x = 483, y = 22
#
# minimal solution to x^2 - 483 * y^2 = 1 is x = 22, y = 1
#
# minimal solution to x^2 - 485 * y^2 = 1 is x = 969, y = 44
#
# minimal solution to x^2 - 486 * y^2 = 1 is x = 485, y = 22
#
# minimal solution to x^2 - 487 * y^2 = 1 is x = 51906073840568, y = 2352088722477
#
# minimal solution to x^2 - 488 * y^2 = 1 is x = 243, y = 11
#
# minimal solution to x^2 - 489 * y^2 = 1 is x = 7592629975, y = 343350596
#
# minimal solution to x^2 - 490 * y^2 = 1 is x = 1039681, y = 46968
#
# minimal solution to x^2 - 491 * y^2 = 1 is x = 93628044170, y = 4225374483
#
# minimal solution to x^2 - 492 * y^2 = 1 is x = 29767, y = 1342
#
# minimal solution to x^2 - 493 * y^2 = 1 is x = 935662752649, y = 42140131020
#
# minimal solution to x^2 - 494 * y^2 = 1 is x = 73035, y = 3286
#
# minimal solution to x^2 - 495 * y^2 = 1 is x = 89, y = 4
#
# minimal solution to x^2 - 496 * y^2 = 1 is x = 4620799, y = 207480
#
# minimal solution to x^2 - 497 * y^2 = 1 is x = 1201887, y = 53912
#
# minimal solution to x^2 - 498 * y^2 = 1 is x = 179777, y = 8056
#
# minimal solution to x^2 - 499 * y^2 = 1 is x = 4490, y = 201
#
# minimal solution to x^2 - 500 * y^2 = 1 is x = 930249, y = 41602
#
# minimal solution to x^2 - 501 * y^2 = 1 is x = 11242731902975, y = 502288218432
#
# minimal solution to x^2 - 502 * y^2 = 1 is x = 3832352837, y = 171046278
#
# minimal solution to x^2 - 503 * y^2 = 1 is x = 24648, y = 1099
#
# minimal solution to x^2 - 504 * y^2 = 1 is x = 449, y = 20
#
# minimal solution to x^2 - 505 * y^2 = 1 is x = 809, y = 36
#
# minimal solution to x^2 - 506 * y^2 = 1 is x = 45, y = 2
#
# minimal solution to x^2 - 507 * y^2 = 1 is x = 1351, y = 60
#
# minimal solution to x^2 - 508 * y^2 = 1 is x = 44757606858751, y = 1985797689600
#
# minimal solution to x^2 - 509 * y^2 = 1 is x = 313201220822405001, y = 13882400040814700
#
# minimal solution to x^2 - 510 * y^2 = 1 is x = 271, y = 12
#
# minimal solution to x^2 - 511 * y^2 = 1 is x = 4188548960, y = 185290497
#
# minimal solution to x^2 - 512 * y^2 = 1 is x = 665857, y = 29427
#
# minimal solution to x^2 - 513 * y^2 = 1 is x = 13771351, y = 608020
#
# minimal solution to x^2 - 514 * y^2 = 1 is x = 4625, y = 204
#
# minimal solution to x^2 - 515 * y^2 = 1 is x = 17406, y = 767
#
# minimal solution to x^2 - 516 * y^2 = 1 is x = 16855, y = 742
#
# minimal solution to x^2 - 517 * y^2 = 1 is x = 590968985399, y = 25990786260
#
# minimal solution to x^2 - 518 * y^2 = 1 is x = 2367, y = 104
#
# minimal solution to x^2 - 519 * y^2 = 1 is x = 14851876, y = 651925
#
# minimal solution to x^2 - 520 * y^2 = 1 is x = 6499, y = 285
#
# minimal solution to x^2 - 521 * y^2 = 1 is x = 32961431500035201, y = 1444066532654320
#
# minimal solution to x^2 - 522 * y^2 = 1 is x = 19603, y = 858
#
# minimal solution to x^2 - 523 * y^2 = 1 is x = 81810300626, y = 3577314675
#
# minimal solution to x^2 - 524 * y^2 = 1 is x = 225144199, y = 9835470
#
# minimal solution to x^2 - 525 * y^2 = 1 is x = 6049, y = 264
#
# minimal solution to x^2 - 526 * y^2 = 1 is x = 84056091546952933775, y = 3665019757324295532
#
# minimal solution to x^2 - 527 * y^2 = 1 is x = 528, y = 23
#
# minimal solution to x^2 - 528 * y^2 = 1 is x = 23, y = 1
#
# minimal solution to x^2 - 530 * y^2 = 1 is x = 1059, y = 46
#
# minimal solution to x^2 - 531 * y^2 = 1 is x = 530, y = 23
#
# minimal solution to x^2 - 532 * y^2 = 1 is x = 2588599, y = 112230
#
# minimal solution to x^2 - 533 * y^2 = 1 is x = 74859849, y = 3242540
#
# minimal solution to x^2 - 534 * y^2 = 1 is x = 3678725, y = 159194
#
# minimal solution to x^2 - 535 * y^2 = 1 is x = 1618804, y = 69987
#
# minimal solution to x^2 - 536 * y^2 = 1 is x = 145925, y = 6303
#
# minimal solution to x^2 - 537 * y^2 = 1 is x = 192349463, y = 8300492
#
# minimal solution to x^2 - 538 * y^2 = 1 is x = 9536081203, y = 411129654
#
# minimal solution to x^2 - 539 * y^2 = 1 is x = 3970, y = 171
#
# minimal solution to x^2 - 540 * y^2 = 1 is x = 119071, y = 5124
#
# minimal solution to x^2 - 541 * y^2 = 1 is x = 3707453360023867028800645599667005001, y = 159395869721270110077187138775196900
#
# minimal solution to x^2 - 542 * y^2 = 1 is x = 4293183, y = 184408
#
# minimal solution to x^2 - 543 * y^2 = 1 is x = 669337, y = 28724
#
# minimal solution to x^2 - 544 * y^2 = 1 is x = 2449, y = 105
#
# minimal solution to x^2 - 545 * y^2 = 1 is x = 1961, y = 84
#
# minimal solution to x^2 - 546 * y^2 = 1 is x = 701, y = 30
#
# minimal solution to x^2 - 547 * y^2 = 1 is x = 160177601264642, y = 6848699678673
#
# minimal solution to x^2 - 548 * y^2 = 1 is x = 6083073, y = 259856
#
# minimal solution to x^2 - 549 * y^2 = 1 is x = 1766319049, y = 75384660
#
# minimal solution to x^2 - 550 * y^2 = 1 is x = 30580901, y = 1303974
#
# minimal solution to x^2 - 551 * y^2 = 1 is x = 8380, y = 357
#
# minimal solution to x^2 - 552 * y^2 = 1 is x = 47, y = 2
#
# minimal solution to x^2 - 553 * y^2 = 1 is x = 624635837407, y = 26562217704
#
# minimal solution to x^2 - 554 * y^2 = 1 is x = 60756099699, y = 2581279330
#
# minimal solution to x^2 - 555 * y^2 = 1 is x = 1814, y = 77
#
# minimal solution to x^2 - 556 * y^2 = 1 is x = 12032115501124999, y = 510275358434250
#
# minimal solution to x^2 - 557 * y^2 = 1 is x = 27849, y = 1180
#
# minimal solution to x^2 - 558 * y^2 = 1 is x = 7937, y = 336
#
# minimal solution to x^2 - 559 * y^2 = 1 is x = 506568295, y = 21425556
#
# minimal solution to x^2 - 560 * y^2 = 1 is x = 71, y = 3
#
# minimal solution to x^2 - 561 * y^2 = 1 is x = 522785, y = 22072
#
# minimal solution to x^2 - 562 * y^2 = 1 is x = 220938497, y = 9319728
#
# minimal solution to x^2 - 563 * y^2 = 1 is x = 68122, y = 2871
#
# minimal solution to x^2 - 564 * y^2 = 1 is x = 95, y = 4
#
# minimal solution to x^2 - 565 * y^2 = 1 is x = 435259412378569, y = 18311501103948
#
# minimal solution to x^2 - 566 * y^2 = 1 is x = 95609285, y = 4018758
#
# minimal solution to x^2 - 567 * y^2 = 1 is x = 2024, y = 85
#
# minimal solution to x^2 - 568 * y^2 = 1 is x = 143, y = 6
#
# minimal solution to x^2 - 569 * y^2 = 1 is x = 16760473211643448449, y = 702635588524014320
#
# minimal solution to x^2 - 570 * y^2 = 1 is x = 191, y = 8
#
# minimal solution to x^2 - 571 * y^2 = 1 is x = 181124355061630786130, y = 7579818350628982587
#
# minimal solution to x^2 - 572 * y^2 = 1 is x = 287, y = 12
#
# minimal solution to x^2 - 573 * y^2 = 1 is x = 383, y = 16
#
# minimal solution to x^2 - 574 * y^2 = 1 is x = 575, y = 24
#
# minimal solution to x^2 - 575 * y^2 = 1 is x = 24, y = 1
#
# minimal solution to x^2 - 577 * y^2 = 1 is x = 1153, y = 48
#
# minimal solution to x^2 - 578 * y^2 = 1 is x = 577, y = 24
#
# minimal solution to x^2 - 579 * y^2 = 1 is x = 385, y = 16
#
# minimal solution to x^2 - 580 * y^2 = 1 is x = 289, y = 12
#
# minimal solution to x^2 - 581 * y^2 = 1 is x = 152071153975, y = 6308974548
#
# minimal solution to x^2 - 582 * y^2 = 1 is x = 193, y = 8
#
# minimal solution to x^2 - 583 * y^2 = 1 is x = 8429543, y = 349116
#
# minimal solution to x^2 - 584 * y^2 = 1 is x = 145, y = 6
#
# minimal solution to x^2 - 585 * y^2 = 1 is x = 33281, y = 1376
#
# minimal solution to x^2 - 586 * y^2 = 1 is x = 33867877212256207699, y = 1399069112058008310
#
# minimal solution to x^2 - 587 * y^2 = 1 is x = 1907162, y = 78717
#
# minimal solution to x^2 - 588 * y^2 = 1 is x = 97, y = 4
#
# minimal solution to x^2 - 589 * y^2 = 1 is x = 41423166067036218751, y = 1706811823063746000
#
# minimal solution to x^2 - 590 * y^2 = 1 is x = 5781, y = 238
#
# minimal solution to x^2 - 591 * y^2 = 1 is x = 165676, y = 6815
#
# minimal solution to x^2 - 592 * y^2 = 1 is x = 73, y = 3
#
# minimal solution to x^2 - 593 * y^2 = 1 is x = 721517598849, y = 29629176560
#
# minimal solution to x^2 - 594 * y^2 = 1 is x = 1098305, y = 45064
#
# minimal solution to x^2 - 595 * y^2 = 1 is x = 18514, y = 759
#
# minimal solution to x^2 - 596 * y^2 = 1 is x = 25801741449, y = 1056880510
#
# minimal solution to x^2 - 597 * y^2 = 1 is x = 463287093751, y = 18961078500
#
# minimal solution to x^2 - 598 * y^2 = 1 is x = 1574351, y = 64380
#
# minimal solution to x^2 - 599 * y^2 = 1 is x = 24686379794520, y = 1008658133851
#
# minimal solution to x^2 - 600 * y^2 = 1 is x = 49, y = 2
#
# minimal solution to x^2 - 601 * y^2 = 1 is x = 38902815462492318420311478049, y = 1586878942101888360258625080
#
# minimal solution to x^2 - 602 * y^2 = 1 is x = 687, y = 28
#
# minimal solution to x^2 - 603 * y^2 = 1 is x = 48842, y = 1989
#
# minimal solution to x^2 - 604 * y^2 = 1 is x = 5972991296311683199, y = 243037569063951720
#
# minimal solution to x^2 - 605 * y^2 = 1 is x = 930249, y = 37820
#
# minimal solution to x^2 - 606 * y^2 = 1 is x = 42187499, y = 1713750
#
# minimal solution to x^2 - 607 * y^2 = 1 is x = 164076033968, y = 6659640783
#
# minimal solution to x^2 - 608 * y^2 = 1 is x = 2737, y = 111
#
# minimal solution to x^2 - 609 * y^2 = 1 is x = 605695, y = 24544
#
# minimal solution to x^2 - 610 * y^2 = 1 is x = 10323982819, y = 418005846
#
# minimal solution to x^2 - 611 * y^2 = 1 is x = 236926, y = 9585
#
# minimal solution to x^2 - 612 * y^2 = 1 is x = 2177, y = 88
#
# minimal solution to x^2 - 613 * y^2 = 1 is x = 464018873584078278910994299849, y = 18741545784831997880308784340
#
# minimal solution to x^2 - 614 * y^2 = 1 is x = 348291186245, y = 14055888354
#
# minimal solution to x^2 - 615 * y^2 = 1 is x = 124, y = 5
#
# minimal solution to x^2 - 616 * y^2 = 1 is x = 21295, y = 858
#
# minimal solution to x^2 - 617 * y^2 = 1 is x = 3363593612801313, y = 135413180018248
#
# minimal solution to x^2 - 618 * y^2 = 1 is x = 10093, y = 406
#
# minimal solution to x^2 - 619 * y^2 = 1 is x = 517213510553282930, y = 20788566180548739
#
# minimal solution to x^2 - 620 * y^2 = 1 is x = 249, y = 10
#
# minimal solution to x^2 - 621 * y^2 = 1 is x = 7775, y = 312
#
# minimal solution to x^2 - 622 * y^2 = 1 is x = 13804370063, y = 553504812
#
# minimal solution to x^2 - 623 * y^2 = 1 is x = 624, y = 25
#
# minimal solution to x^2 - 624 * y^2 = 1 is x = 25, y = 1
#
# minimal solution to x^2 - 626 * y^2 = 1 is x = 1251, y = 50
#
# minimal solution to x^2 - 627 * y^2 = 1 is x = 626, y = 25
#
# minimal solution to x^2 - 628 * y^2 = 1 is x = 46698728731849, y = 1863482146110
#
# minimal solution to x^2 - 629 * y^2 = 1 is x = 123245001, y = 4914100
#
# minimal solution to x^2 - 630 * y^2 = 1 is x = 251, y = 10
#
# minimal solution to x^2 - 631 * y^2 = 1 is x = 48961575312998650035560, y = 1949129537575151036427
#
# minimal solution to x^2 - 632 * y^2 = 1 is x = 7743, y = 308
#
# minimal solution to x^2 - 633 * y^2 = 1 is x = 440772247, y = 17519124
#
# minimal solution to x^2 - 634 * y^2 = 1 is x = 8711856945587257031251, y = 345992039259400361250
#
# minimal solution to x^2 - 635 * y^2 = 1 is x = 126, y = 5
#
# minimal solution to x^2 - 636 * y^2 = 1 is x = 3505951, y = 139020
#
# minimal solution to x^2 - 637 * y^2 = 1 is x = 1419278889601, y = 56233877040
#
# minimal solution to x^2 - 638 * y^2 = 1 is x = 42283, y = 1674
#
# minimal solution to x^2 - 639 * y^2 = 1 is x = 24220799, y = 958160
#
# minimal solution to x^2 - 640 * y^2 = 1 is x = 1039681, y = 41097
#
# minimal solution to x^2 - 641 * y^2 = 1 is x = 2609429220845977814049, y = 103066257550962737720
#
# minimal solution to x^2 - 642 * y^2 = 1 is x = 5777, y = 228
#
# minimal solution to x^2 - 643 * y^2 = 1 is x = 1988960193026, y = 78436933185
#
# minimal solution to x^2 - 644 * y^2 = 1 is x = 11775, y = 464
#
# minimal solution to x^2 - 645 * y^2 = 1 is x = 1024001, y = 40320
#
# minimal solution to x^2 - 646 * y^2 = 1 is x = 305, y = 12
#
# minimal solution to x^2 - 647 * y^2 = 1 is x = 120187368, y = 4725053
#
# minimal solution to x^2 - 648 * y^2 = 1 is x = 19601, y = 770
#
# minimal solution to x^2 - 649 * y^2 = 1 is x = 1123593226162199, y = 44104892095380
#
# minimal solution to x^2 - 650 * y^2 = 1 is x = 51, y = 2
#
# minimal solution to x^2 - 651 * y^2 = 1 is x = 1735, y = 68
#
# minimal solution to x^2 - 652 * y^2 = 1 is x = 8212499464321351, y = 321626301297510
#
# minimal solution to x^2 - 653 * y^2 = 1 is x = 10499986568677299849, y = 410896226494013260
#
# minimal solution to x^2 - 654 * y^2 = 1 is x = 8915765, y = 348634
#
# minimal solution to x^2 - 655 * y^2 = 1 is x = 737709209, y = 28824684
#
# minimal solution to x^2 - 656 * y^2 = 1 is x = 2049, y = 80
#
# minimal solution to x^2 - 657 * y^2 = 1 is x = 2281249, y = 89000
#
# minimal solution to x^2 - 658 * y^2 = 1 is x = 1693, y = 66
#
# minimal solution to x^2 - 659 * y^2 = 1 is x = 5930, y = 231
#
# minimal solution to x^2 - 660 * y^2 = 1 is x = 1079, y = 42
#
# minimal solution to x^2 - 661 * y^2 = 1 is x = 16421658242965910275055840472270471049, y = 638728478116949861246791167518480580
#
# minimal solution to x^2 - 662 * y^2 = 1 is x = 1718102501, y = 66775950
#
# minimal solution to x^2 - 663 * y^2 = 1 is x = 103, y = 4
#
# minimal solution to x^2 - 664 * y^2 = 1 is x = 1700902565, y = 66007821
#
# minimal solution to x^2 - 665 * y^2 = 1 is x = 13719, y = 532
#
# minimal solution to x^2 - 666 * y^2 = 1 is x = 27365201, y = 1060380
#
# minimal solution to x^2 - 667 * y^2 = 1 is x = 107119097, y = 4147668
#
# minimal solution to x^2 - 668 * y^2 = 1 is x = 56447, y = 2184
#
# minimal solution to x^2 - 669 * y^2 = 1 is x = 14226117859054135, y = 550013492618436
#
# minimal solution to x^2 - 670 * y^2 = 1 is x = 5791211, y = 223734
#
# minimal solution to x^2 - 671 * y^2 = 1 is x = 58620, y = 2263
#
# minimal solution to x^2 - 672 * y^2 = 1 is x = 337, y = 13
#
# minimal solution to x^2 - 673 * y^2 = 1 is x = 4765506835465395993032041249, y = 183696788896587421699032600
#
# minimal solution to x^2 - 674 * y^2 = 1 is x = 675, y = 26
#
# minimal solution to x^2 - 675 * y^2 = 1 is x = 26, y = 1
#
# minimal solution to x^2 - 677 * y^2 = 1 is x = 1353, y = 52
#
# minimal solution to x^2 - 678 * y^2 = 1 is x = 677, y = 26
#
# minimal solution to x^2 - 679 * y^2 = 1 is x = 17792625320, y = 682818291
#
# minimal solution to x^2 - 680 * y^2 = 1 is x = 339, y = 13
#
# minimal solution to x^2 - 681 * y^2 = 1 is x = 10743166003415, y = 411679015748
#
# minimal solution to x^2 - 682 * y^2 = 1 is x = 1197901, y = 45870
#
# minimal solution to x^2 - 683 * y^2 = 1 is x = 170067682, y = 6507459
#
# minimal solution to x^2 - 684 * y^2 = 1 is x = 57799, y = 2210
#
# minimal solution to x^2 - 685 * y^2 = 1 is x = 95592800063517769, y = 3652413145693884
#
# minimal solution to x^2 - 686 * y^2 = 1 is x = 10850138895, y = 414260228
#
# minimal solution to x^2 - 687 * y^2 = 1 is x = 165337, y = 6308
#
# minimal solution to x^2 - 688 * y^2 = 1 is x = 24248647, y = 924471
#
# minimal solution to x^2 - 689 * y^2 = 1 is x = 105, y = 4
#
# minimal solution to x^2 - 690 * y^2 = 1 is x = 1471, y = 56
#
# minimal solution to x^2 - 691 * y^2 = 1 is x = 31138100617500578690, y = 1184549173291009383
#
# minimal solution to x^2 - 692 * y^2 = 1 is x = 2499849, y = 95030
#
# minimal solution to x^2 - 693 * y^2 = 1 is x = 246401, y = 9360
#
# minimal solution to x^2 - 694 * y^2 = 1 is x = 38782105445014642382885, y = 1472148590903997672114
#
# minimal solution to x^2 - 695 * y^2 = 1 is x = 33639, y = 1276
#
# minimal solution to x^2 - 696 * y^2 = 1 is x = 1451, y = 55
#
# minimal solution to x^2 - 697 * y^2 = 1 is x = 34849, y = 1320
#
# minimal solution to x^2 - 698 * y^2 = 1 is x = 51999603, y = 1968214
#
# minimal solution to x^2 - 699 * y^2 = 1 is x = 2271050, y = 85899
#
# minimal solution to x^2 - 700 * y^2 = 1 is x = 8193151, y = 309672
#
# minimal solution to x^2 - 701 * y^2 = 1 is x = 277631049, y = 10485980
#
# minimal solution to x^2 - 702 * y^2 = 1 is x = 53, y = 2
#
# minimal solution to x^2 - 703 * y^2 = 1 is x = 1159172, y = 43719
#
# minimal solution to x^2 - 704 * y^2 = 1 is x = 79201, y = 2985
#
# minimal solution to x^2 - 705 * y^2 = 1 is x = 237161, y = 8932
#
# minimal solution to x^2 - 706 * y^2 = 1 is x = 34595, y = 1302
#
# minimal solution to x^2 - 707 * y^2 = 1 is x = 2526, y = 95
#
# minimal solution to x^2 - 708 * y^2 = 1 is x = 62423, y = 2346
#
# minimal solution to x^2 - 709 * y^2 = 1 is x = 665782673992201, y = 25003993164540
#
# minimal solution to x^2 - 710 * y^2 = 1 is x = 1279, y = 48
#
# minimal solution to x^2 - 711 * y^2 = 1 is x = 80, y = 3
#
# minimal solution to x^2 - 712 * y^2 = 1 is x = 1601, y = 60
#
# minimal solution to x^2 - 713 * y^2 = 1 is x = 5286367, y = 197976
#
# minimal solution to x^2 - 714 * y^2 = 1 is x = 4115, y = 154
#
# minimal solution to x^2 - 715 * y^2 = 1 is x = 75646, y = 2829
#
# minimal solution to x^2 - 716 * y^2 = 1 is x = 35115719688199, y = 1312336060110
#
# minimal solution to x^2 - 717 * y^2 = 1 is x = 6998399, y = 261360
#
# minimal solution to x^2 - 718 * y^2 = 1 is x = 8933399183036079503, y = 333391496474140716
#
# minimal solution to x^2 - 719 * y^2 = 1 is x = 403480310400, y = 15047276489
#
# minimal solution to x^2 - 720 * y^2 = 1 is x = 161, y = 6
#
# minimal solution to x^2 - 721 * y^2 = 1 is x = 18632176943292415, y = 693898530122112
#
# minimal solution to x^2 - 722 * y^2 = 1 is x = 22619537, y = 841812
#
# minimal solution to x^2 - 723 * y^2 = 1 is x = 242, y = 9
#
# minimal solution to x^2 - 724 * y^2 = 1 is x = 2469645423824185801, y = 91783649341730970
#
# minimal solution to x^2 - 725 * y^2 = 1 is x = 9801, y = 364
#
# minimal solution to x^2 - 726 * y^2 = 1 is x = 485, y = 18
#
# minimal solution to x^2 - 727 * y^2 = 1 is x = 728, y = 27
#
# minimal solution to x^2 - 728 * y^2 = 1 is x = 27, y = 1
#
# minimal solution to x^2 - 730 * y^2 = 1 is x = 1459, y = 54
#
# minimal solution to x^2 - 731 * y^2 = 1 is x = 730, y = 27
#
# minimal solution to x^2 - 732 * y^2 = 1 is x = 487, y = 18
#
# minimal solution to x^2 - 733 * y^2 = 1 is x = 195307849, y = 7213860
#
# minimal solution to x^2 - 734 * y^2 = 1 is x = 10394175, y = 383656
#
# minimal solution to x^2 - 735 * y^2 = 1 is x = 244, y = 9
#
# minimal solution to x^2 - 736 * y^2 = 1 is x = 24335, y = 897
#
# minimal solution to x^2 - 737 * y^2 = 1 is x = 252975383, y = 9318468
#
# minimal solution to x^2 - 738 * y^2 = 1 is x = 163, y = 6
#
# minimal solution to x^2 - 739 * y^2 = 1 is x = 98015661073616742153890, y = 3605564376516452758671
#
# minimal solution to x^2 - 740 * y^2 = 1 is x = 9249, y = 340
#
# minimal solution to x^2 - 741 * y^2 = 1 is x = 7352695, y = 270108
#
# minimal solution to x^2 - 742 * y^2 = 1 is x = 263091151, y = 9658380
#
# minimal solution to x^2 - 743 * y^2 = 1 is x = 714024, y = 26195
#
# minimal solution to x^2 - 744 * y^2 = 1 is x = 7501, y = 275
#
# minimal solution to x^2 - 745 * y^2 = 1 is x = 12769001, y = 467820
#
# minimal solution to x^2 - 746 * y^2 = 1 is x = 61268974069299, y = 2243216519470
#
# minimal solution to x^2 - 747 * y^2 = 1 is x = 82, y = 3
#
# minimal solution to x^2 - 748 * y^2 = 1 is x = 5658247, y = 206886
#
# minimal solution to x^2 - 749 * y^2 = 1 is x = 1084616384895, y = 39631020176
#
# minimal solution to x^2 - 750 * y^2 = 1 is x = 2550251, y = 93122
#
# minimal solution to x^2 - 751 * y^2 = 1 is x = 7293318466794882424418960, y = 266136970677206024456793
#
# minimal solution to x^2 - 752 * y^2 = 1 is x = 4607, y = 168
#
# minimal solution to x^2 - 753 * y^2 = 1 is x = 308526027863, y = 11243313484
#
# minimal solution to x^2 - 754 * y^2 = 1 is x = 836977699, y = 30480930
#
# ...
#
# minimal solution to x^2 - 770 * y^2 = 1 is x = 111, y = 4
#
# minimal solution to x^2 - 771 * y^2 = 1 is x = 2989136930, y = 107651137
#
# minimal solution to x^2 - 772 * y^2 = 1 is x = 6224323426849, y = 224018302020
#
# minimal solution to x^2 - 773 * y^2 = 1 is x = 3607394696649, y = 129748968980
#
# minimal solution to x^2 - 774 * y^2 = 1 is x = 10405, y = 374
#
# minimal solution to x^2 - 775 * y^2 = 1 is x = 4620799, y = 165984
#
# minimal solution to x^2 - 776 * y^2 = 1 is x = 195, y = 7
#
# minimal solution to x^2 - 777 * y^2 = 1 is x = 223, y = 8
#
# minimal solution to x^2 - 778 * y^2 = 1 is x = 5964562960504723, y = 213839942395674
#
# minimal solution to x^2 - 779 * y^2 = 1 is x = 11785490, y = 422259
#
# minimal solution to x^2 - 780 * y^2 = 1 is x = 391, y = 14
#
# minimal solution to x^2 - 781 * y^2 = 1 is x = 67606199, y = 2419140
#
# minimal solution to x^2 - 782 * y^2 = 1 is x = 783, y = 28
#
# minimal solution to x^2 - 783 * y^2 = 1 is x = 28, y = 1
#
# minimal solution to x^2 - 785 * y^2 = 1 is x = 1569, y = 56
#
# minimal solution to x^2 - 786 * y^2 = 1 is x = 785, y = 28
#
# minimal solution to x^2 - 787 * y^2 = 1 is x = 34625394242, y = 1234262007
#
# minimal solution to x^2 - 788 * y^2 = 1 is x = 393, y = 14
#
# minimal solution to x^2 - 789 * y^2 = 1 is x = 16116667272575, y = 573768548496
#
# minimal solution to x^2 - 790 * y^2 = 1 is x = 6616066879, y = 235389096
#
# minimal solution to x^2 - 791 * y^2 = 1 is x = 225, y = 8
#
# minimal solution to x^2 - 792 * y^2 = 1 is x = 197, y = 7
#
# minimal solution to x^2 - 793 * y^2 = 1 is x = 4393, y = 156
#
# minimal solution to x^2 - 794 * y^2 = 1 is x = 1828310451, y = 64884310
#
# minimal solution to x^2 - 795 * y^2 = 1 is x = 6626, y = 235
#
# minimal solution to x^2 - 796 * y^2 = 1 is x = 529178298454520220799, y = 18756227493635055480
#
# minimal solution to x^2 - 797 * y^2 = 1 is x = 1221759532448649, y = 43276943002540
#
# minimal solution to x^2 - 798 * y^2 = 1 is x = 113, y = 4
#
# minimal solution to x^2 - 799 * y^2 = 1 is x = 424, y = 15
#
# minimal solution to x^2 - 800 * y^2 = 1 is x = 19601, y = 693
#
# minimal solution to x^2 - 801 * y^2 = 1 is x = 500002000001, y = 17666702000
#
# minimal solution to x^2 - 802 * y^2 = 1 is x = 295496099, y = 10434330
#
# minimal solution to x^2 - 803 * y^2 = 1 is x = 7226, y = 255
#
# minimal solution to x^2 - 804 * y^2 = 1 is x = 515095, y = 18166
#
# minimal solution to x^2 - 805 * y^2 = 1 is x = 1514868641, y = 53392104
#
# minimal solution to x^2 - 806 * y^2 = 1 is x = 6166395, y = 217202
#
# minimal solution to x^2 - 807 * y^2 = 1 is x = 51841948, y = 1824923
#
# minimal solution to x^2 - 808 * y^2 = 1 is x = 19731763, y = 694161
#
# minimal solution to x^2 - 809 * y^2 = 1 is x = 376455160998025676163201, y = 13235458622462202510640
#
# minimal solution to x^2 - 810 * y^2 = 1 is x = 27379, y = 962
#
# minimal solution to x^2 - 811 * y^2 = 1 is x = 1382072163578616410, y = 48531117622921197
#
# minimal solution to x^2 - 812 * y^2 = 1 is x = 57, y = 2
#
# minimal solution to x^2 - 813 * y^2 = 1 is x = 2167, y = 76
#
# minimal solution to x^2 - 814 * y^2 = 1 is x = 4206992174549, y = 147454999410
#
# minimal solution to x^2 - 815 * y^2 = 1 is x = 156644, y = 5487
#
# minimal solution to x^2 - 816 * y^2 = 1 is x = 4999, y = 175
#
# minimal solution to x^2 - 817 * y^2 = 1 is x = 343, y = 12
#
# minimal solution to x^2 - 818 * y^2 = 1 is x = 40899, y = 1430
#
# minimal solution to x^2 - 819 * y^2 = 1 is x = 1574, y = 55
#
# minimal solution to x^2 - 820 * y^2 = 1 is x = 39689, y = 1386
#
# minimal solution to x^2 - 821 * y^2 = 1 is x = 9000987377460935993101449, y = 314136625452886403879740
#
# minimal solution to x^2 - 822 * y^2 = 1 is x = 7397, y = 258
#
# minimal solution to x^2 - 823 * y^2 = 1 is x = 235170474903644006168, y = 8197527430497636651
#
# minimal solution to x^2 - 824 * y^2 = 1 is x = 59535, y = 2074
#
# minimal solution to x^2 - 825 * y^2 = 1 is x = 48599, y = 1692
#
# minimal solution to x^2 - 826 * y^2 = 1 is x = 222239304685, y = 7732694382
#
# minimal solution to x^2 - 827 * y^2 = 1 is x = 900602, y = 31317
#
# minimal solution to x^2 - 828 * y^2 = 1 is x = 1151, y = 40
#
# minimal solution to x^2 - 829 * y^2 = 1 is x = 479835713751049, y = 16665383182260
#
# minimal solution to x^2 - 830 * y^2 = 1 is x = 146411, y = 5082
#
# minimal solution to x^2 - 831 * y^2 = 1 is x = 9799705, y = 339948
#
# minimal solution to x^2 - 832 * y^2 = 1 is x = 842401, y = 29205
#
# minimal solution to x^2 - 833 * y^2 = 1 is x = 9478657, y = 328416
#
# minimal solution to x^2 - 834 * y^2 = 1 is x = 6552578705, y = 226897244
#
# minimal solution to x^2 - 835 * y^2 = 1 is x = 34336355806, y = 1188258591
#
# minimal solution to x^2 - 836 * y^2 = 1 is x = 46551, y = 1610
#
# minimal solution to x^2 - 837 * y^2 = 1 is x = 12151, y = 420
#
# minimal solution to x^2 - 838 * y^2 = 1 is x = 42112785797, y = 1454762046
#
# minimal solution to x^2 - 839 * y^2 = 1 is x = 840, y = 29
#
# minimal solution to x^2 - 840 * y^2 = 1 is x = 29, y = 1
#
# minimal solution to x^2 - 842 * y^2 = 1 is x = 1683, y = 58
#
# minimal solution to x^2 - 843 * y^2 = 1 is x = 842, y = 29
#
# minimal solution to x^2 - 844 * y^2 = 1 is x = 154962314660167628644999, y = 5334022845973817148450
#
# minimal solution to x^2 - 845 * y^2 = 1 is x = 299537289, y = 10304396
#
# minimal solution to x^2 - 846 * y^2 = 1 is x = 2143295, y = 73688
#
# minimal solution to x^2 - 847 * y^2 = 1 is x = 8193151, y = 281520
#
# minimal solution to x^2 - 848 * y^2 = 1 is x = 66249, y = 2275
#
# minimal solution to x^2 - 849 * y^2 = 1 is x = 1501654712948695, y = 51536656330476
#
# minimal solution to x^2 - 850 * y^2 = 1 is x = 2449, y = 84
#
# minimal solution to x^2 - 851 * y^2 = 1 is x = 8418574, y = 288585
#
# minimal solution to x^2 - 852 * y^2 = 1 is x = 194399, y = 6660
#
# minimal solution to x^2 - 853 * y^2 = 1 is x = 215454135724113414336120649, y = 7377009103065498851032020
#
# minimal solution to x^2 - 854 * y^2 = 1 is x = 1294299, y = 44290
#
# minimal solution to x^2 - 855 * y^2 = 1 is x = 3041, y = 104
#
# minimal solution to x^2 - 856 * y^2 = 1 is x = 695359189925, y = 23766887823
#
# minimal solution to x^2 - 857 * y^2 = 1 is x = 131822292741249, y = 4502963741200
#
# minimal solution to x^2 - 858 * y^2 = 1 is x = 703, y = 24
#
# minimal solution to x^2 - 859 * y^2 = 1 is x = 2058844771979643060124010, y = 70246877103894937291269
#
# minimal solution to x^2 - 860 * y^2 = 1 is x = 3871, y = 132
#
# minimal solution to x^2 - 861 * y^2 = 1 is x = 541601801, y = 18457740
#
# minimal solution to x^2 - 862 * y^2 = 1 is x = 358022566147312125503, y = 12194296994921665128
#
# minimal solution to x^2 - 863 * y^2 = 1 is x = 18524026608, y = 630565199
#
# minimal solution to x^2 - 864 * y^2 = 1 is x = 470449, y = 16005
#
# minimal solution to x^2 - 865 * y^2 = 1 is x = 242688628535063329, y = 8251660923733224
#
# minimal solution to x^2 - 866 * y^2 = 1 is x = 42435, y = 1442
#
# minimal solution to x^2 - 867 * y^2 = 1 is x = 70226, y = 2385
#
# minimal solution to x^2 - 868 * y^2 = 1 is x = 3844063, y = 130476
#
# minimal solution to x^2 - 869 * y^2 = 1 is x = 60192738698751, y = 2041898807200
#
# minimal solution to x^2 - 870 * y^2 = 1 is x = 59, y = 2
#
# minimal solution to x^2 - 871 * y^2 = 1 is x = 19442812076, y = 658794555
#
# minimal solution to x^2 - 872 * y^2 = 1 is x = 126003, y = 4267
#
# minimal solution to x^2 - 873 * y^2 = 1 is x = 62809633, y = 2125784
#
# minimal solution to x^2 - 874 * y^2 = 1 is x = 3725, y = 126
#
# minimal solution to x^2 - 875 * y^2 = 1 is x = 120126, y = 4061
#
# minimal solution to x^2 - 876 * y^2 = 1 is x = 10951, y = 370
#
# minimal solution to x^2 - 877 * y^2 = 1 is x = 116476476553, y = 3933131148
#
# minimal solution to x^2 - 878 * y^2 = 1 is x = 9314703, y = 314356
#
# minimal solution to x^2 - 879 * y^2 = 1 is x = 107245324, y = 3617295
#
# minimal solution to x^2 - 880 * y^2 = 1 is x = 89, y = 3
#
# minimal solution to x^2 - 881 * y^2 = 1 is x = 22606256615916825861249, y = 761624136944072910800
#
# minimal solution to x^2 - 882 * y^2 = 1 is x = 19601, y = 660
#
# minimal solution to x^2 - 883 * y^2 = 1 is x = 34878475759617272473442, y = 1173754162936357802169
#
# minimal solution to x^2 - 884 * y^2 = 1 is x = 1665, y = 56
#
# minimal solution to x^2 - 885 * y^2 = 1 is x = 119, y = 4
#
# minimal solution to x^2 - 886 * y^2 = 1 is x = 7743524593057655851637765, y = 260148796464024194850378
#
# minimal solution to x^2 - 887 * y^2 = 1 is x = 469224, y = 15755
#
# minimal solution to x^2 - 888 * y^2 = 1 is x = 149, y = 5
#
# minimal solution to x^2 - 889 * y^2 = 1 is x = 13231974717803657215, y = 443786188413453504
#
# minimal solution to x^2 - 890 * y^2 = 1 is x = 179, y = 6
#
# minimal solution to x^2 - 891 * y^2 = 1 is x = 3970, y = 133
#
# minimal solution to x^2 - 892 * y^2 = 1 is x = 100351, y = 3360
#
# minimal solution to x^2 - 893 * y^2 = 1 is x = 6091434999, y = 203842100
#
# minimal solution to x^2 - 894 * y^2 = 1 is x = 299, y = 10
#
# minimal solution to x^2 - 895 * y^2 = 1 is x = 359, y = 12
#
# minimal solution to x^2 - 896 * y^2 = 1 is x = 449, y = 15
#
# minimal solution to x^2 - 897 * y^2 = 1 is x = 599, y = 20
#
# minimal solution to x^2 - 898 * y^2 = 1 is x = 899, y = 30
#
# minimal solution to x^2 - 899 * y^2 = 1 is x = 30, y = 1
#
# minimal solution to x^2 - 901 * y^2 = 1 is x = 1801, y = 60
#
# minimal solution to x^2 - 902 * y^2 = 1 is x = 901, y = 30
#
# minimal solution to x^2 - 903 * y^2 = 1 is x = 601, y = 20
#
# minimal solution to x^2 - 904 * y^2 = 1 is x = 451, y = 15
#
# minimal solution to x^2 - 905 * y^2 = 1 is x = 361, y = 12
#
# minimal solution to x^2 - 906 * y^2 = 1 is x = 301, y = 10
#
# minimal solution to x^2 - 907 * y^2 = 1 is x = 123823410343073497682, y = 4111488857741309517
#
# minimal solution to x^2 - 908 * y^2 = 1 is x = 102151, y = 3390
#
# minimal solution to x^2 - 909 * y^2 = 1 is x = 80801, y = 2680
#
# minimal solution to x^2 - 910 * y^2 = 1 is x = 181, y = 6
#
# minimal solution to x^2 - 911 * y^2 = 1 is x = 371832584927520, y = 12319363142953
#
# minimal solution to x^2 - 912 * y^2 = 1 is x = 151, y = 5
#
# minimal solution to x^2 - 913 * y^2 = 1 is x = 515734243080407, y = 17068312251564
#
# minimal solution to x^2 - 914 * y^2 = 1 is x = 62563299, y = 2069410
#
# minimal solution to x^2 - 915 * y^2 = 1 is x = 121, y = 4
#
# minimal solution to x^2 - 916 * y^2 = 1 is x = 5848201, y = 193230
#
# minimal solution to x^2 - 917 * y^2 = 1 is x = 823604599, y = 27197820
#
# minimal solution to x^2 - 918 * y^2 = 1 is x = 4120901, y = 136010
#
# minimal solution to x^2 - 919 * y^2 = 1 is x = 4481603010937119451551263720, y = 147834442396536759781499589
#
# minimal solution to x^2 - 920 * y^2 = 1 is x = 91, y = 3
#
# minimal solution to x^2 - 921 * y^2 = 1 is x = 2522057712835735, y = 83104627139412
#
# minimal solution to x^2 - 922 * y^2 = 1 is x = 351605368773852499, y = 11579506138834350
#
# minimal solution to x^2 - 923 * y^2 = 1 is x = 638, y = 21
#
# minimal solution to x^2 - 924 * y^2 = 1 is x = 11551, y = 380
#
# minimal solution to x^2 - 925 * y^2 = 1 is x = 1555849, y = 51156
#
# minimal solution to x^2 - 926 * y^2 = 1 is x = 304560297142335, y = 10008472361032
#
# minimal solution to x^2 - 927 * y^2 = 1 is x = 227528, y = 7473
#
# minimal solution to x^2 - 928 * y^2 = 1 is x = 768555217, y = 25229061
#
# minimal solution to x^2 - 929 * y^2 = 1 is x = 13224937103288377430049, y = 433896111669844912840
#
# minimal solution to x^2 - 930 * y^2 = 1 is x = 61, y = 2
#
# minimal solution to x^2 - 931 * y^2 = 1 is x = 6681448801, y = 218975640
#
# minimal solution to x^2 - 932 * y^2 = 1 is x = 1072400673, y = 35127652
#
# minimal solution to x^2 - 933 * y^2 = 1 is x = 75263, y = 2464
#
# minimal solution to x^2 - 934 * y^2 = 1 is x = 3034565, y = 99294
#
# minimal solution to x^2 - 935 * y^2 = 1 is x = 1376, y = 45
#
# minimal solution to x^2 - 936 * y^2 = 1 is x = 5201, y = 170
#
# minimal solution to x^2 - 937 * y^2 = 1 is x = 480644425002415999597113107233, y = 15701968936415353889062192632
#
# minimal solution to x^2 - 938 * y^2 = 1 is x = 17151, y = 560
#
# minimal solution to x^2 - 939 * y^2 = 1 is x = 122695, y = 4004
#
# minimal solution to x^2 - 940 * y^2 = 1 is x = 4231, y = 138
#
# minimal solution to x^2 - 941 * y^2 = 1 is x = 1068924905989944201, y = 34845956052079180
#
# minimal solution to x^2 - 942 * y^2 = 1 is x = 106133, y = 3458
#
# minimal solution to x^2 - 943 * y^2 = 1 is x = 737, y = 24
#
# minimal solution to x^2 - 944 * y^2 = 1 is x = 561799, y = 18285
#
# minimal solution to x^2 - 945 * y^2 = 1 is x = 275561, y = 8964
#
# minimal solution to x^2 - 946 * y^2 = 1 is x = 45225786400145, y = 1470417148788
#
# minimal solution to x^2 - 947 * y^2 = 1 is x = 13509645362, y = 439004487
#
# minimal solution to x^2 - 948 * y^2 = 1 is x = 228151, y = 7410
#
# minimal solution to x^2 - 949 * y^2 = 1 is x = 609622436806639069525576201, y = 19789181711517243032971740
#
# minimal solution to x^2 - 950 * y^2 = 1 is x = 202501, y = 6570
#
# minimal solution to x^2 - 951 * y^2 = 1 is x = 224208076, y = 7270445
#
# minimal solution to x^2 - 952 * y^2 = 1 is x = 11663, y = 378
#
# minimal solution to x^2 - 953 * y^2 = 1 is x = 15090531843660371073, y = 488830275367615376
#
# minimal solution to x^2 - 954 * y^2 = 1 is x = 32080051, y = 1038630
#
# minimal solution to x^2 - 955 * y^2 = 1 is x = 2095256249, y = 67800900
#
# minimal solution to x^2 - 956 * y^2 = 1 is x = 76759023628799, y = 2482564242480
#
# minimal solution to x^2 - 957 * y^2 = 1 is x = 14849, y = 480
#
# minimal solution to x^2 - 958 * y^2 = 1 is x = 16762522330425599, y = 541572514048560
#
# minimal solution to x^2 - 959 * y^2 = 1 is x = 960, y = 31
#
# minimal solution to x^2 - 960 * y^2 = 1 is x = 31, y = 1
#
# minimal solution to x^2 - 962 * y^2 = 1 is x = 1923, y = 62
#
# minimal solution to x^2 - 963 * y^2 = 1 is x = 962, y = 31
#
# minimal solution to x^2 - 964 * y^2 = 1 is x = 10085143557001249, y = 324820602522300
#
# minimal solution to x^2 - 965 * y^2 = 1 is x = 446526729, y = 14374204
#
# minimal solution to x^2 - 966 * y^2 = 1 is x = 57499, y = 1850
#
# minimal solution to x^2 - 967 * y^2 = 1 is x = 4649532557817485528, y = 149518887194649693
#
# minimal solution to x^2 - 968 * y^2 = 1 is x = 19601, y = 630
#
# minimal solution to x^2 - 969 * y^2 = 1 is x = 13588951, y = 436540
#
# minimal solution to x^2 - 970 * y^2 = 1 is x = 215395035859, y = 6915917802
#
# minimal solution to x^2 - 971 * y^2 = 1 is x = 12479806786330, y = 400496058813
#
# minimal solution to x^2 - 972 * y^2 = 1 is x = 9863382151, y = 316368130
#
# minimal solution to x^2 - 973 * y^2 = 1 is x = 903223, y = 28956
#
# minimal solution to x^2 - 974 * y^2 = 1 is x = 488825745235215, y = 15662987185124
#
# minimal solution to x^2 - 975 * y^2 = 1 is x = 1249, y = 40
#
# minimal solution to x^2 - 976 * y^2 = 1 is x = 1766319049, y = 56538495
#
# minimal solution to x^2 - 977 * y^2 = 1 is x = 108832847723078562849, y = 3481871275306470280
#
# minimal solution to x^2 - 978 * y^2 = 1 is x = 118337, y = 3784
#
# minimal solution to x^2 - 979 * y^2 = 1 is x = 360449, y = 11520
#
# minimal solution to x^2 - 980 * y^2 = 1 is x = 51841, y = 1656
#
# minimal solution to x^2 - 981 * y^2 = 1 is x = 158070671986249, y = 5046808151700
#
# minimal solution to x^2 - 982 * y^2 = 1 is x = 8837, y = 282
#
# minimal solution to x^2 - 983 * y^2 = 1 is x = 284088, y = 9061
#
# minimal solution to x^2 - 984 * y^2 = 1 is x = 88805, y = 2831
#
# minimal solution to x^2 - 985 * y^2 = 1 is x = 332929, y = 10608
#
# minimal solution to x^2 - 986 * y^2 = 1 is x = 49299, y = 1570
#
# minimal solution to x^2 - 987 * y^2 = 1 is x = 377, y = 12
#
# minimal solution to x^2 - 988 * y^2 = 1 is x = 14549450527, y = 462879684
#
# minimal solution to x^2 - 989 * y^2 = 1 is x = 550271588560695, y = 17497618534396
#
# minimal solution to x^2 - 990 * y^2 = 1 is x = 881, y = 28
#
# minimal solution to x^2 - 991 * y^2 = 1 is x = 379516400906811930638014896080, y = 12055735790331359447442538767
#
# minimal solution to x^2 - 992 * y^2 = 1 is x = 63, y = 2
#
# minimal solution to x^2 - 993 * y^2 = 1 is x = 2647, y = 84
#
# minimal solution to x^2 - 994 * y^2 = 1 is x = 1135, y = 36
#
# minimal solution to x^2 - 995 * y^2 = 1 is x = 8835999, y = 280120
#
# minimal solution to x^2 - 996 * y^2 = 1 is x = 8553815, y = 271038
#
# minimal solution to x^2 - 997 * y^2 = 1 is x = 14418057673, y = 456624468
#
# minimal solution to x^2 - 998 * y^2 = 1 is x = 984076901, y = 31150410
#
# minimal solution to x^2 - 999 * y^2 = 1 is x = 102688615, y = 3248924
#
# 661
# 16421658242965910275055840472270471049
